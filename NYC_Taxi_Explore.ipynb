# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('nyc-taxi-zone-lookup.csv')

# %%
df.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df
# Out:
#      LocationID        Borough                                 Zone  \
# 0             1            EWR                       Newark Airport
# 1             2         Queens                          Jamaica Bay
# 2             3          Bronx              Allerton/Pelham Gardens
# 3             4      Manhattan                        Alphabet City
# 4             5  Staten Island                        Arden Heights
# 5             6  Staten Island              Arrochar/Fort Wadsworth
# 6             7         Queens                              Astoria
# 7             8         Queens                         Astoria Park
# 8             9         Queens                           Auburndale
# 9            10         Queens                         Baisley Park
# 10           11       Brooklyn                           Bath Beach
# 11           12      Manhattan                         Battery Park
# 12           13      Manhattan                    Battery Park City
# ...

# %%
df2 = pd.read_pickle('nyc-2017-yellow-taxi-trips-to-airport.pkl.gz')

# %%
df2.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2533072 entries, 0 to 2533071
# Data columns (total 18 columns):
# Unnamed: 0               int32
# VendorID                 category
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count          int8
# trip_distance            float16
# RatecodeID               category
# store_and_fwd_flag       category
# PULocationID             int16
# DOLocationID             int16
# payment_type             category
# fare_amount              float16
# extra                    float16
# mta_tax                  float16
# tip_amount               float16
# tolls_amount             float16
# improvement_surcharge    float16
# total_amount             float16
# dtypes: category(4), datetime64[ns](2), float16(8), int16(2), int32(1), int8(1)
# memory usage: 108.7 MB

# %%
df2.PULocationID = pd.to_numeric(df2.PULocationID, downcast='integer')

# %%
df2.DOLocationID = pd.to_numeric(df2.DOLocationID, downcast='integer')

# %%
df2.PULocationID.isin([263,264]).value_counts()
# Out:
# False    2471546
# True       61526
# Name: PULocationID, dtype: int64

# %%
df2.DOLocationID.isin([263,264]).value_counts()
# Out:
# False    2533072
# Name: DOLocationID, dtype: int64

# %%
100*61526/2471546
# Out:
# 2.4893730482863763

# %%
df.Zone.value_counts()[df.Zone.value_counts()>1]
# Out:
# Governor's Island/Ellis Island/Liberty Island    3
# Corona                                           2
# Name: Zone, dtype: int64

# %%
df.set_index('LocationID', inplace=True)

# %%
zones=df.Zone.to_dict()

# %%
df2.PULocationID.apply(lambda id: zones.get(id))
# Out:
# 0                Greenwich Village North
# 1                        Lenox Hill West
# 2                           Central Park
# 3                       Garment District
# 4                            Murray Hill
# 5               Financial District South
# 6                  Upper West Side South
# 7                         Midtown Center
# 8               Financial District North
# 9                            Murray Hill
# 10                        Midtown Center
# 11                      Garment District
# 12                           Murray Hill
# 13                          Clinton East
# 14                         Midtown North
# 15             Times Sq/Theatre District
# 16                        Midtown Center
# 17                   Lincoln Square West
# 18                   UN/Turtle Bay South
# 19                           JFK Airport
# 20                        Yorkville West
# 21                   UN/Turtle Bay South
# 22                              Union Sq
# ...

# %%
#df['pickup_zone'] = 
df2.PULocationID.apply(lambda id: df[df.LocationID == id].Zone)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-4122ddc9fe3d> in <module>()
#       1 #df['pickup_zone'] =
# ----> 2 df2.PULocationID.apply(lambda id: df[df.LocationID == id].Zone)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-49-4122ddc9fe3d> in <lambda>(id)
#       1 #df['pickup_zone'] =
# ----> 2 df2.PULocationID.apply(lambda id: df[df.LocationID == id].Zone)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
# ...

# %%
df[df.LocationID == 138].Zone
# Out:
# 137    LaGuardia Airport
# Name: Zone, dtype: object
